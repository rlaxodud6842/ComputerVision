# %% [markdown]
# # 데이터셋 불러오기

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

data_train, data_test = tf.keras.datasets.mnist.load_data()
(image_train, labels_train)= data_train
(image_test, labels_test)= data_test

# %% [markdown]
# # 한개 표시

# %%
plt.imshow(image_train[0], cmap = plt.cm.binary)
plt.title(labels_train[0])
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # 정규화

# %%
image_train, image_test = image_train/255.0, image_test/255.0

# %% [markdown]
# # 모델

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model2=keras.models.Sequential([
    layers.Dense(128,activation = 'relu',input_shape = (28*28,)),
    layers.Flatten(input_shape = (28,28)),
    layers.Dense(128,activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(10,activation = 'softmax')
])
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               100480
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
image_train_v=image_train.reshape((-1,28*28))
image_test_v=image_test.reshape((-1,28*28))
print(image_train_v.shape)
print(image_test_v.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
history = model2.fit(image_train_v, labels_train, epochs=50, batch_size=100,validation_data=(image_test_v,labels_test),verbose=1)
# Out:
# Epoch 1/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.1326 - val_accuracy: 0.9813
# Epoch 2/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.1540 - val_accuracy: 0.9793
# Epoch 3/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1381 - val_accuracy: 0.9814
# Epoch 4/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.1329 - val_accuracy: 0.9806
# Epoch 5/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1561 - val_accuracy: 0.9786
# Epoch 6/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.1604 - val_accuracy: 0.9779
# Epoch 7/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.1495 - val_accuracy: 0.9797
# Epoch 8/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1713 - val_accuracy: 0.9807
# Epoch 9/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.1529 - val_accuracy: 0.9806
# Epoch 10/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.1525 - val_accuracy: 0.9800
# Epoch 11/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.1513 - val_accuracy: 0.9810
# Epoch 12/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1607 - val_accuracy: 0.9802
# Epoch 13/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.1461 - val_accuracy: 0.9814
# Epoch 14/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.1897 - val_accuracy: 0.9783
# Epoch 15/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.1731 - val_accuracy: 0.9779
# Epoch 16/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1485 - val_accuracy: 0.9806
# Epoch 17/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1487 - val_accuracy: 0.9801
# Epoch 18/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1761 - val_accuracy: 0.9788
# Epoch 19/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1487 - val_accuracy: 0.9809
# Epoch 20/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.1388 - val_accuracy: 0.9815
# Epoch 21/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.1601 - val_accuracy: 0.9803
# Epoch 22/50
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.1685 - val_accuracy: 0.9795
# Epoch 23/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.1585 - val_accuracy: 0.9794
# Epoch 24/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.1416 - val_accuracy: 0.9800
# Epoch 25/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1398 - val_accuracy: 0.9814
# Epoch 26/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.1703 - val_accuracy: 0.9786
# Epoch 27/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1887 - val_accuracy: 0.9765
# Epoch 28/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.1496 - val_accuracy: 0.9806
# Epoch 29/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1672 - val_accuracy: 0.9786
# Epoch 30/50
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.1914 - val_accuracy: 0.9761
# Epoch 31/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1632 - val_accuracy: 0.9797
# Epoch 32/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1665 - val_accuracy: 0.9808
# Epoch 33/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1592 - val_accuracy: 0.9816
# Epoch 34/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1588 - val_accuracy: 0.9816
# Epoch 35/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.1652 - val_accuracy: 0.9813
# Epoch 36/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1839 - val_accuracy: 0.9804
# Epoch 37/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1808 - val_accuracy: 0.9803
# Epoch 38/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1679 - val_accuracy: 0.9810
# Epoch 39/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.1785 - val_accuracy: 0.9800
# Epoch 40/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1724 - val_accuracy: 0.9822
# Epoch 41/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1910 - val_accuracy: 0.9794
# Epoch 42/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1847 - val_accuracy: 0.9811
# Epoch 43/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.1843 - val_accuracy: 0.9805
# Epoch 44/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.1958 - val_accuracy: 0.9812
# Epoch 45/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.1893 - val_accuracy: 0.9796
# Epoch 46/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1942 - val_accuracy: 0.9795
# Epoch 47/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.1706 - val_accuracy: 0.9817
# Epoch 48/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.1721 - val_accuracy: 0.9795
# Epoch 49/50
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.2078 - val_accuracy: 0.9784
# Epoch 50/50
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1877 - val_accuracy: 0.9804

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # 검증

# %%
model2.evaluate(image_train_v, labels_train)
model2.evaluate(image_test_v, labels_test )
# Out:
# 1875/1875 [==============================] - 2s 907us/step - loss: 0.0024 - accuracy: 0.9992
# 313/313 [==============================] - 0s 788us/step - loss: 0.1444 - accuracy: 0.9797
# [0.1444152444601059, 0.9797000288963318]

# %%
output1=model2.predict(image_train_v)
#output1=model1.predict(x_train_v[0].reshape(-1,784))
print(output1.shape)
print(output1[0].max())
print(output1[0].argmax())
# Out:
# 1875/1875 [==============================] - 1s 678us/step
# (60000, 10)
# 0.99999994
# 5

# %%
import cv2

img2=cv2.imread('2.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('img2',img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
model2.save('my_model_fashion_mnist') 
#model.save('my_model_fashion_mnist.keras') 
# del model
# model2 = keras.models.load_model('my_model_fashion_mnist')
#model = keras.models.load_model('my_model_fashion_mnist.keras')
# Out:
# INFO:tensorflow:Assets written to: my_model_fashion_mnist\assets

# %%
img2n = cv2.resize(img2,(28,28))
img2nt = cv2.bitwise_not(img2n)/255.0

from matplotlib import pyplot as plt
#plt.imshow(x_train[0], cmap = plt.cm.binary)
plt.imshow(img2nt, cmap = plt.cm.gray)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.plot(history.history['accuracy'], label='Training Accuracy')
#       2 plt.title('Training Accuracy per Epoch')
#       3 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined
